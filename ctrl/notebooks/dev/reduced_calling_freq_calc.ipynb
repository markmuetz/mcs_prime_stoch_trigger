# %%
# Numbers taken from MCSP_Calling_freq.*.png lower right titles.

import numpy as np

a = np.array([3.054, 2.936, 3.099, 3.022, 2.920, 2.862, 2.850, 2.691, 2.760, 3.016, 3.157, 3.160])

a.mean()
# Out:
# 2.9605833333333336

# %%
1 / a.mean()
# Out:
# 0.33777127255326933

# %%
print(f'{1 / a.mean():.3f}')
# Out:
# 0.338
